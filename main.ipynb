# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
# %cd "/content/drive/My Drive/MLILAB/study/SimCLR"
# !ls
# !TCMALLOC_LARGE_ALLOC_REPORT_THRESHOLD=21329330176

# %%
# 최초 실행시 데이터 복사
# !mkdir data
# !cp "/content/drive/My Drive/MLILAB/study/SimCLR/data/stl10_binary.tar.gz" ./data/stl10_binary.tar.gz

# %%
# With 
# !python "/content/drive/My Drive/MLILAB/study/SimCLR/main.py"
