# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
# %cd "/content/drive/My Drive/MLILAB/study/SimCLR"
# !ls
# !TCMALLOC_LARGE_ALLOC_REPORT_THRESHOLD=21329330176

# %%
# !date
import time
time.localtime()

# %%
# !python "/content/drive/My Drive/MLILAB/study/SimCLR/main.py" --num_worker 0 --batch_size 512 --option 'unlabel_train' --epochs 45 --dataset 'STL-10'
